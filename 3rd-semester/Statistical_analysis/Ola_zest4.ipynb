# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import statistics as st
import numpy as np 
import pandas as pd
from math import ceil
import statsmodels.api as sm
import seaborn as sns

# %%
#zestaw 4 zad 6

# %%
x=[37,39,39,41,45,46,48,53,59,61,61,64,67,69,69,73]

# %%
#wartosci podsrawowych sratystyk
a=st.mean(x)
b=st.median(x)
c=st.stdev(x)
d=st.mode(x)
print(a,b,c,d)
# Out:
# 54.4375 56.0 12.355666716126652 39

# %%
#wybierz odpowiednia liczbe klas dla rozkladu czestosci
y=list(range(35,85,10))
print(y)
# Out:
# [35, 45, 55, 65, 75]

# %%
plt.hist(x,bins=y, rwidth=0.85,density=1,cumulative=1)
# Out:
# (array([0.25, 0.5 , 0.75, 1.  ]),
#  array([35, 45, 55, 65, 75]),
#  <BarContainer object of 4 artists>)

# %%
#rysowanie histogramu z polem rownym 1-nie zapisujemy cumulative
plt.hist(x,bins=y,rwidth=0.85,density=1)
# Out:
# (array([0.025, 0.025, 0.025, 0.025]),
#  array([35, 45, 55, 65, 75]),
#  <BarContainer object of 4 artists>)

# %%
#skumulowany rozklad czestosci-dopisujemy cumulative
plt.hist(x,bins=y,rwidth=0.85,density=1,cumulative=1)
# Out:
# (array([0.25, 0.5 , 0.75, 1.  ]),
#  array([35, 45, 55, 65, 75]),
#  <BarContainer object of 4 artists>)

# %%
#zadanie 8 zestaw 4

# %%
waga=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\Waga.xlsx')
print(waga)
# Out:
#     Waga
# 0     53
# 1     56
# 2     57
# 3     58
# 4     59
# 5     61
# 6     61
# 7     61
# 8     61
# 9     62
# 10    62
# 11    63
# 12    63
# 13    64
# 14    64
# 15    65
# 16    65
# 17    65
# 18    65
# 19    66
# 20    66
# 21    66
# 22    66
# 23    67
# 24    67
# 25    68
# 26    68
# 27    68
# 28    69
# 29    69
# 30    70
# 31    71
# 32    71
# 33    73
# 34    73
# 35    74
# 36    74
# 37    76
# 38    78
# 39    79

# %%
srednia=waga['Waga'].mean()
mediana=waga['Waga'].median()
odchylenie=waga['Waga'].std()
moda=waga['Waga'].mode()
print(srednia,mediana,odchylenie,moda)
# Out:
# 66.1 66.0 5.908707177786062 0    61
# 1    65
# 2    66
# dtype: int64

# %%
#histogram
waga.hist('Waga',bins=[50,55,60,65,70,75,80])
plt.show()

# %%
#hisogram z polem rownym 1
waga.hist('Waga',bins=[50,55,60,65,70,75,80],density=1)
plt.show()

# %%
#skumulowany rozklad czestosci
waga.hist('Waga',bins=[50,55,60,65,70,75,80],density=1,cumulative=1)
plt.show()

# %%
#kwantyl dolny,gorny,rozstep,rozstep kwartylowy,wspolczynnik zmiennosci sredniej
q1=waga['Waga'].quantile(0.25)
print(q1)
q3=waga['Waga'].quantile(0.75)
print(q3)
q2=waga['Waga'].quantile(0.5)
print(q2)
rozstep=waga['Waga'].max()-waga['Waga'].min()
print(rozstep)
rk=q3-q1
print(rk)
wzs=odchylenie/srednia
print(wzs)
# Out:
# 62.0
# 69.25
# 66.0
# 26
# 7.25
# 0.08939042629025813

# %%
#zestaw 4 zadanie 10

# %%
antybiotyki=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\Antybiotyki2.xls','Dane 2')
print(antybiotyki)
# Out:
#     ID  Dni hospitalizacji  Wiek Płeć  Temperatura Antybiotyk  \
# 0    1                   5    30    K         37.2          N
# 1    2                  10    73    K         36.7          N
# 2    3                   6    40    K         37.2          N
# 3    4                  11    47    K         36.8          N
# 4    5                   5    25    K         36.9          N
# 5    6                  14    82    M         36.0          T
# 6    7                  30    60    M         37.5          T
# 7    8                  11    56    K         37.0          N
# 8    9                  17    43    K         36.7          N
# 9   10                   3    50    M         36.7          N
# 10  11                   9    59    K         36.4          N
# 11  12                   3     4    M         36.6          N
# 12  13                   8    22    K         37.5          T
# 13  14                   8    33    K         36.9          T
# 14  15                   5    20    K         36.9          N
# 15  16                   5    32    M         37.2          N
# 16  17                   7    36    M         37.3          T
# 17  18                   4    69    M         36.7          N
# 18  19                   3    47    M         36.1          T
# 19  20                   7    22    M         36.8          N
# 20  21                   9    11    M         36.8          N
# 21  22                  11    19    M         37.0          T
# 22  23                  11    67    K         36.4          N
# 23  24                   9    43    K         37.0          N
# 24  25                   4    41    K         36.7          N
#
#    Kultury bakterii  WBC
# 0                 N    8
# 1                 T    5
# 2                 N   12
# 3                 N    4
# 4                 N   11
# 5                 N    6
# 6                 T    8
# 7                 N    7
# 8                 N    7
# 9                 T   12
# 10                T    7
# 11                N    3
# 12                N   11
# 13                T   14
# 14                T   11
# 15                N    9
# 16                N    6
# 17                N    6
# 18                N    5
# 19                N    6
# 20                N   10
# 21                N   14
# 22                N    4
# 23                N    5
# 24                N    5

# %%
dane=antybiotyki[['Dni hospitalizacji','Wiek','Temperatura','WBC']]
print(dane)
# Out:
#     Dni hospitalizacji  Wiek  Temperatura  WBC
# 0                    5    30         37.2    8
# 1                   10    73         36.7    5
# 2                    6    40         37.2   12
# 3                   11    47         36.8    4
# 4                    5    25         36.9   11
# 5                   14    82         36.0    6
# 6                   30    60         37.5    8
# 7                   11    56         37.0    7
# 8                   17    43         36.7    7
# 9                    3    50         36.7   12
# 10                   9    59         36.4    7
# 11                   3     4         36.6    3
# 12                   8    22         37.5   11
# 13                   8    33         36.9   14
# 14                   5    20         36.9   11
# 15                   5    32         37.2    9
# 16                   7    36         37.3    6
# 17                   4    69         36.7    6
# 18                   3    47         36.1    5
# 19                   7    22         36.8    6
# 20                   9    11         36.8   10
# 21                  11    19         37.0   14
# 22                  11    67         36.4    4
# 23                   9    43         37.0    5
# 24                   4    41         36.7    5

# %%
srednia=dane.mean()
print(srednia)
mediana=dane.median()
print(mediana)
odchylenie=dane.std()
print(odchylenie)
rozstep=dane.max()-dane.min()
print(rozstep)
# Out:
# Dni hospitalizacji     8.60
# Wiek                  41.24
# Temperatura           36.84
# WBC                    7.84
# dtype: float64
# Dni hospitalizacji     8.0
# Wiek                  41.0
# Temperatura           36.8
# WBC                    7.0
# dtype: float64
# Dni hospitalizacji     5.715476
# Wiek                  20.102404
# Temperatura            0.374166
# WBC                    3.210400
# dtype: float64
# Dni hospitalizacji    27.0
# Wiek                  78.0
# Temperatura            1.5
# WBC                   11.0
# dtype: float64

# %%
otrzym=dane.loc[antybiotyki['Antybiotyk']=='T']
notrzym=dane.loc[antybiotyki['Antybiotyk']=='N']

# %%
srednia=otrzym.mean()
print(srednia)
mediana=otrzym.median()
print(mediana)
odchylenie=otrzym.std()
print(odchylenie)
rozstep=otrzym.max()-otrzym.min()
print(rozstep)
# Out:
# Dni hospitalizacji    11.571429
# Wiek                  42.714286
# Temperatura           36.900000
# WBC                    9.142857
# dtype: float64
# Dni hospitalizacji     8.0
# Wiek                  36.0
# Temperatura           37.0
# WBC                    8.0
# dtype: float64
# Dni hospitalizacji     8.810167
# Wiek                  22.328713
# Temperatura            0.624500
# WBC                    3.848314
# dtype: float64
# Dni hospitalizacji    27.0
# Wiek                  63.0
# Temperatura            1.5
# WBC                    9.0
# dtype: float64

# %%
srednia=notrzym.mean()
print(srednia)
mediana=notrzym.median()
print(mediana)
odchylenie=notrzym.std()
print(odchylenie)
rozstep=notrzym.max()-otrzym.min()
print(rozstep)
# Out:
# Dni hospitalizacji     7.444444
# Wiek                  40.666667
# Temperatura           36.816667
# WBC                    7.333333
# dtype: float64
# Dni hospitalizacji     6.5
# Wiek                  42.0
# Temperatura           36.8
# WBC                    7.0
# dtype: float64
# Dni hospitalizacji     3.697729
# Wiek                  19.831644
# Temperatura            0.240710
# WBC                    2.890146
# dtype: float64
# Dni hospitalizacji    14.0
# Wiek                  54.0
# Temperatura            1.2
# WBC                    7.0
# dtype: float64

# %%
babki=dane.loc[antybiotyki['Płeć']=='K']
chlopy=dane.loc[antybiotyki['Płeć']=='M']
babki["WBC"].hist()
plt.show()
chlopy["WBC"].hist()
plt.show()

# %%
dane['Wiek'].hist()
plt.show()

# %%
#inny sposob
dane=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\Antybiotyki2.xls',sheet_name='Dane 2')
print(dane)
dane.hist('WBC',by='Płeć',bins=5)
plt.show()
# Out:
#     ID  Dni hospitalizacji  Wiek Płeć  Temperatura Antybiotyk  \
# 0    1                   5    30    K         37.2          N
# 1    2                  10    73    K         36.7          N
# 2    3                   6    40    K         37.2          N
# 3    4                  11    47    K         36.8          N
# 4    5                   5    25    K         36.9          N
# 5    6                  14    82    M         36.0          T
# 6    7                  30    60    M         37.5          T
# 7    8                  11    56    K         37.0          N
# 8    9                  17    43    K         36.7          N
# 9   10                   3    50    M         36.7          N
# 10  11                   9    59    K         36.4          N
# 11  12                   3     4    M         36.6          N
# 12  13                   8    22    K         37.5          T
# 13  14                   8    33    K         36.9          T
# 14  15                   5    20    K         36.9          N
# 15  16                   5    32    M         37.2          N
# 16  17                   7    36    M         37.3          T
# 17  18                   4    69    M         36.7          N
# 18  19                   3    47    M         36.1          T
# 19  20                   7    22    M         36.8          N
# 20  21                   9    11    M         36.8          N
# 21  22                  11    19    M         37.0          T
# 22  23                  11    67    K         36.4          N
# 23  24                   9    43    K         37.0          N
# 24  25                   4    41    K         36.7          N
#
#    Kultury bakterii  WBC
# 0                 N    8
# 1                 T    5
# 2                 N   12
# 3                 N    4
# 4                 N   11
# 5                 N    6
# 6                 T    8
# 7                 N    7
# 8                 N    7
# 9                 T   12
# 10                T    7
# 11                N    3
# 12                N   11
# 13                T   14
# 14                T   11
# 15                N    9
# 16                N    6
# 17                N    6
# 18                N    5
# 19                N    6
# 20                N   10
# 21                N   14
# 22                N    4
# 23                N    5
# 24                N    5

# %%
dane.hist('Wiek',bins=12)
plt.show()

# %%
#zestaw 4 zadanie 12

# %%
dane2=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\WagaWzrost.xls')
print(dane2)
# Out:
#     Waga  Wzrost
# 0   83.9     185
# 1   99.0     180
# 2   63.8     168
# 3   71.3     173
# 4   65.3     175
# 5   79.6     183
# 6   70.3     184
# 7   69.2     174
# 8   56.4     164
# 9   66.2     169
# 10  88.7     205
# 11  59.7     161
# 12  64.6     177
# 13  78.8     174

# %%
srednia1=dane2['Waga'].mean()
mediana1=dane2['Waga'].median()
os1=dane2['Waga'].std()
wzs1=os1/srednia1
#wzm=do tego potrzebne jest q1,q2,q3
Q2_waga=dane2['Waga'].quantile(0.5)
Q1_waga=dane2['Waga'].quantile(0.25)
Q3_waga=dane2['Waga'].quantile(0.75)
#odchylenie cwiartkowe
Q_waga=(Q3_waga-Q1_waga)/2
#wspolczynnik zmiennosci mediany
wzm1=Q_waga/Q2_waga
print(srednia1,mediana1,os1,wzs1,wzm1)
# Out:
# 72.62857142857143 69.75 11.943355318491378 0.16444431005003862 0.10483870967741936

# %%
#zestaw 4 zad 14

# %%
dane3=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\Rozkłady.xlsx')
print(dane3)
# Out:
#     Proba 1  Proba 2  Proba 3  Proba 4
# 0        67       31      102     12.1
# 1        70       43       55     12.1
# 2        63       30       70     12.4
# 3        65       30       95     12.1
# 4        68       38       73     12.1
# 5        60       26       79     12.2
# 6        70       29       60     12.2
# 7        64       55       73     12.2
# 8        69       46       89     11.9
# 9        61       26       85     12.2
# 10       66       29       72     12.3
# 11       65       57       92     12.3
# 12       71       34       76     11.7
# 13       62       34       93     12.3
# 14       66       36       76     12.3
# 15       68       40       97     12.4
# 16       64       28       10     12.4
# 17       67       26       70     12.1
# 18       62       66       85     12.4
# 19       66       63       25     12.4
# 20       65       30       83     12.5
# 21       63       33       58     11.8
# 22       66       24       10     12.5
# 23       65       35       92     12.5
# 24       63       34       82     12.5
# 25       69       40       87     11.6
# 26       62       24      104     11.6
# 27       67       29       75     12.0
# 28       59       24       80     11.6
# 29       66       27       66     11.6
# 30       65       35       93     11.7
# 31       63       33       90     12.3
# 32       65       75       84     11.7
# 33       60       38       73     11.7
# 34       67       34       98     11.7
# 35       64       85       79     11.8
# 36       68       29       35     12.5
# 37       61       40       71     11.8
# 38       69       41       90     11.8
# 39       65       35       71     11.8
# 40       62       26       63     11.9
# 41       67       34       58     11.9
# 42       70       19       82     11.9
# 43       64       23       72     12.2
# 44       63       28       93     11.9
# 45       68       26       44     12.0
# 46       64       31       65     11.9
# 47       65       25       77     12.0
# 48       61       22       81     12.0
# 49       66       28       77     12.0

# %%
wzrost=dane3['Proba 1']
srednia=wzrost.mean()
mediana=wzrost.median()
skosnosc=wzrost.skew()
print(srednia,mediana,skosnosc)
# Out:
# 65.12 65.0 -0.020323180421975836

# %%
plt.hist(wzrost,bins=12)
plt.axvline(srednia,color='red',label='srednia')
plt.axvline(mediana,color='yellow',label='mediana')
plt.legend()
plt.xlabel('wzrost')
plt.show()

# %%
wiek=dane3['Proba 2']
srednia=wiek.mean()
mediana=wiek.median()
skosnosc=wiek.skew()
print(srednia,mediana,skosnosc)
# Out:
# 35.48 32.0 1.9774236639188756

# %%
plt.hist(wiek)
plt.axvline(srednia,color='red',label='srednia')
plt.axvline(mediana,color='yellow',label='mediana')
plt.legend()
plt.xlabel('wiek')
plt.show()

# %%
dlugosc_zycia=dane3['Proba 3']
srednia=dlugosc_zycia.mean()
mediana=dlugosc_zycia.median()
skosnosc=dlugosc_zycia.skew()
print(srednia,mediana,skosnosc)
# Out:
# 74.2 77.0 -1.4986144712878977

# %%
plt.hist(dlugosc_zycia,bins=12)
plt.axvline(srednia,color='red',label='srednia')
plt.axvline(mediana,color='yellow',label='mediana')
plt.legend()
plt.xlabel('dlugosc zycia')
plt.show()

# %%
objetosc=dane3['Proba 4']
srednia=objetosc.mean()
mediana=objetosc.median()
skosnosc=objetosc.skew()
print(srednia,mediana,skosnosc)
# Out:
# 12.056000000000001 12.05 0.015608784033438659

# %%
plt.hist(objetosc,bins=12)
plt.axvline(srednia,color='red',label='srednia')
plt.axvline(mediana,color='yellow',label='mediana')
plt.legend()
plt.xlabel('objetosc')
plt.show()

# %%
#zestaw 4 zadanie 13 ramka wasy

# %%
dane=pd.read_excel(r'C:\Users\olalu\OneDrive\Pulpit\analiza statystyczna\APTT.xls')
print(dane)
# Out:
#    Grupy  APTT
# 0      I  20.7
# 1      I  31.2
# 2      I  24.9
# 3      I  22.9
# 4      I  52.4
# 5      I  29.6
# 6      I  38.3
# 7      I  29.0
# 8      I  20.3
# 9      I  20.9
# 10     I  34.4
# 11     I  28.5
# 12     I  30.1
# 13     I  28.4
# 14     I  46.1
# 15     I  56.6
# 16     I  22.8
# 17     I  33.9
# 18     I  35.5
# 19     I  35.0
# 20     I  22.5
# 21     I  44.8
# 22     I  39.7
# 23     I  39.7
# 24     I  22.8
# 25     I  46.1
# 26     I  29.7
# 27     I  41.6
# 28     I  45.3
# 29     I  54.7
# 30    II  23.9
# 31    II  53.7
# 32    II  23.1
# 33    II  38.9
# 34    II  41.3
# 35    II  23.2
# 36    II  31.6
# 37    II  34.6
# 38    II  24.2
# 39    II  23.7
# 40    II  56.2
# 41    II  24.6
# 42    II  41.3
# 43    II  21.1
# 44    II  35.7
# 45    II  30.2
# 46    II  49.8
# 47    II  34.1
# 48    II  40.7
# 49    II  29.2
# 50    II  27.2
# 51    II  22.6
# 52    II  26.7
# 53    II  39.8
# 54    II  27.4
# 55    II  21.8
# 56    II  48.9
# 57    II  20.1
# 58    II  21.4
# 59    II  23.2

# %%
sns.boxplot(dane['APTT'])
plt.show()
# Out:
# C:\Users\olalu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(style='whitegrid')
sns.boxplot(dane['Grupy'],dane['APTT'], orient='v',order=['II','I'])
plt.show()
# Out:
# C:\Users\olalu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
